# %%
# !pip install transformers datasets jupyterlab ultralytics

# %%
# !pip install torch torchvision torchaudio

# %%
torch.cuda.device_count()
# Out:
# 1

# %%
device = torch.device('cuda')
device
# Out:
# device(type='cuda')

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# Check if CUDA is available
if torch.cuda.is_available():
    device = torch.device('cuda')
    print(f"Running on GPU: {torch.cuda.get_device_name(0)}")  # Display GPU name
#else:
#    device = torch.device('cpu')
#    print("Running on CPU")

# Define your model
model = nn.Linear(10, 5)
model.to(device)  # Move the model to the GPU

# Define a sample input tensor
input_tensor = torch.randn(1, 10).to(device)  # Move the input tensor to the GPU

# Perform forward pass
output_tensor = model(input_tensor)
print(output_tensor)
# Out:
# tensor([[-0.2484,  0.3354, -0.0298, -0.4403,  0.4892]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)

# %%
import torch
x = torch.rand(5, 3)
print(x)
# Out:
# tensor([[0.2068, 0.4425, 0.6150],
#         [0.8433, 0.3701, 0.9726],
#         [0.2116, 0.4482, 0.7982],
#         [0.5261, 0.3998, 0.0951],
#         [0.3806, 0.5607, 0.1302]])

# %%
import os
import urllib.request

# Create a directory for the weights in the current working directory
weights_dir = os.path.join(os.getcwd(), "weights")
os.makedirs(weights_dir, exist_ok=True)

# URLs of the weight files
urls = [
    "https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11s.pt",
]

# Download each file
for url in urls:
    file_name = os.path.join(weights_dir, os.path.basename(url))
    urllib.request.urlretrieve(url, file_name)
    print(f"Downloaded {file_name}")
# Out:
# Downloaded /home/ubuntu/weights/yolo11s.pt

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="YOUR_API_KEY")
project = rf.workspace("zers-qfmok").project("deteksi-plat-nomor-mobil")
version = project.version(7)
dataset = version.download("yolov11")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.2/85.2 KB 2.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 40.6 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 KB 17.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 98.8 MB/s eta 0:00:00:00:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 KB 18.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Deteksi-Plat-Nomor-Mobil-7 in yolov11:: 100%|███| 5858/5858 [00:00<00:00, 7821.63it/s]

# %%
# !yolo task=detect mode=train epochs=50 batch=16 plots=True model=/home/ubuntu/weights/yolo11s.pt data=/home/ubuntu/Deteksi-Plat-Nomor-Mobil-7/data.yaml
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/home/ubuntu/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.107 🚀 Python-3.10.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A10G, 22503MiB)
# ...

# %%
# !yolo task=detect  mode=predict conf=0.25 save=True model=runs/detect/train/weights/best.pt source=plat1-b.jpg
# Out:
# Ultralytics 8.3.107 🚀 Python-3.10.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A10G, 22503MiB)
# YOLO11s summary (fused): 100 layers, 9,413,574 parameters, 0 gradients, 21.3 GFLOPs
#
# image 1/1 /home/ubuntu/plat1-b.jpg: 384x640 1 Ganjil, 68.2ms
# Speed: 5.2ms preprocess, 68.2ms inference, 133.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=detect  mode=predict conf=0.25 save=True model=runs/detect/train/weights/best.pt source=plat1-a.jpg
# Out:
# Ultralytics 8.3.107 🚀 Python-3.10.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A10G, 22503MiB)
# YOLO11s summary (fused): 100 layers, 9,413,574 parameters, 0 gradients, 21.3 GFLOPs
#
# image 1/1 /home/ubuntu/plat1-a.jpg: 224x640 1 Genap, 68.5ms
# Speed: 4.2ms preprocess, 68.5ms inference, 152.0ms postprocess per image at shape (1, 3, 224, 640)
# Results saved to runs/detect/predict4
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
